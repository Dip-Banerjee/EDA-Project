# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_left_wk4 = pd.read_csv('PT17 LEFT_595_imu_week4.csv')

# %%
df_left_wk4.shape
# Out:
# (10320, 7)

# %%
df_left_wk4.isnull().sum()
# Out:
# timestamp    0
# x            0
# y            0
# z            0
# gx           0
# gy           0
# gz           0
# dtype: int64

# %%
# List of features to plot
features = ['x', 'y', 'z', 'gx', 'gy', 'gz']

# Set up the figure size
plt.figure(figsize=(12, 10))

# Loop through each feature and plot the KDE
for i, feature in enumerate(features):
    plt.subplot(3, 2, i + 1)  # Adjust the subplot layout as necessary
    df_left_wk4[feature].plot(kind='kde', title=f'KDE of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Density')

plt.tight_layout()  # Adjust subplots to fit into the figure area.
plt.show()

# %%
# Plotting each sensor data over time
plt.figure(figsize=(12, 8))
plt.subplot(3, 2, 1)
plt.plot(df_left_wk4['timestamp'], df_left_wk4['x'], label='X')
plt.title('X Acceleration')
plt.legend()

plt.subplot(3, 2, 2)
plt.plot(df_left_wk4['timestamp'], df_left_wk4['y'], label='Y')
plt.title('Y Acceleration')
plt.legend()

plt.subplot(3, 2, 3)
plt.plot(df_left_wk4['timestamp'], df_left_wk4['z'], label='Z')
plt.title('Z Acceleration')
plt.legend()

plt.subplot(3, 2, 4)
plt.plot(df_left_wk4['timestamp'], df_left_wk4['gx'], label='Gyro X')
plt.title('Gyro X')
plt.legend()

plt.subplot(3, 2, 5)
plt.plot(df_left_wk4['timestamp'], df_left_wk4['gy'], label='Gyro Y')
plt.title('Gyro Y')
plt.legend()

plt.subplot(3, 2, 6)
plt.plot(df_left_wk4['timestamp'], df_left_wk4['gz'], label='Gyro Z')
plt.title('Gyro Z')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Selecting only sensor data columns if they are named as 'x', 'y', 'z', 'gx', 'gy', 'gz'
sensor_data_columns = ['x', 'y', 'z', 'gx', 'gy', 'gz']
correlation_matrix = df_left_wk4[sensor_data_columns].corr()

# Set up the matplotlib figure
#plt.figure(figsize=(10, 8))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Sensor Data (Wk4)')
plt.show()

# %%
df_left_wk6 = pd.read_csv('PT17 LEFT_595_imu_week6.csv')
df_left_wk8 = pd.read_csv('PT17 LEFT_595_imu_week8.csv')
df_left_wk10 = pd.read_csv('PT17 LEFT_595_imu_week10.csv')
df_left_wk12 = pd.read_csv('PT17 LEFT_595_imu_week12.csv')
df_left_wk14 = pd.read_csv('PT17 LEFT_595_imu_week14.csv')
df_left_wk16 = pd.read_csv('PT17 LEFT_595_imu_week16.csv')

# %%
sensor_data_columns = ['x', 'y', 'z', 'gx', 'gy', 'gz']
correlation_matrix = df_left_wk6[sensor_data_columns].corr()

# Set up the matplotlib figure
#plt.figure(figsize=(10, 8))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Sensor Data (Wk6)')
plt.show()

# %%
sensor_data_columns = ['x', 'y', 'z', 'gx', 'gy', 'gz']
correlation_matrix = df_left_wk8[sensor_data_columns].corr()

# Set up the matplotlib figure
#plt.figure(figsize=(10, 8))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Sensor Data (Wk8)')
plt.show()

# %%
sensor_data_columns = ['x', 'y', 'z', 'gx', 'gy', 'gz']
correlation_matrix = df_left_wk10[sensor_data_columns].corr()

# Set up the matplotlib figure
#plt.figure(figsize=(10, 8))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Sensor Data (Wk10)')
plt.show()

# %%
sensor_data_columns = ['x', 'y', 'z', 'gx', 'gy', 'gz']
correlation_matrix = df_left_wk12[sensor_data_columns].corr()

# Set up the matplotlib figure
#plt.figure(figsize=(10, 8))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Sensor Data (Wk12)')
plt.show()

# %%
sensor_data_columns = ['x', 'y', 'z', 'gx', 'gy', 'gz']
correlation_matrix = df_left_wk14[sensor_data_columns].corr()

# Set up the matplotlib figure
#plt.figure(figsize=(10, 8))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Sensor Data (Wk14)')
plt.show()

# %%
sensor_data_columns = ['x', 'y', 'z', 'gx', 'gy', 'gz']
correlation_matrix = df_left_wk16[sensor_data_columns].corr()

# Set up the matplotlib figure
#plt.figure(figsize=(10, 8))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Sensor Data (Wk16)')
plt.show()
